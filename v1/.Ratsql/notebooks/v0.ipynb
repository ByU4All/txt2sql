# %%
# User Query (NL)
#     │
#     ▼
# [Retriever Layer]
#    ├─ Schema embeddings (table/column names, relationships)
#    ├─ Example queries & docs
#    ├─ Business glossary ("What is revenue?")
#     │
#     ▼
# [Context Builder]
#    ├─ Fetch top-k relevant chunks
#    ├─ Build context (schema + examples)
#     │
#     ▼
# [LLM / SQL Generator]
#    ├─ Generate SQL based on retrieved context
#     │
#     ▼
# [SQL Validator + Dialect Translator (SQLGlot)]
#     │
#     ▼
# [Executor + Feedback Loop]
#    ├─ Execute on proper DB (Trino/Postgres/SQLServer)
#    ├─ Return results or error feedback to re-try generation

# %% [markdown]
# ## 1.1 : Retriever Layer

# %% [markdown]
# ### 1.1.a : Schema embeddings (table/column names, relationships)

# %% [markdown]
# Fetch data from the vector store

# %% [markdown]
# ## 1.2 : Context Builder

# %% [markdown]
# ## 1.3 : LLM / SQL Generator

# %% [markdown]
# ## 1.4 : SQL Validator + Dialect Translator (SQLGlot)

# %% [markdown]
# ## 1.5 : Executor + Feedback Loop
